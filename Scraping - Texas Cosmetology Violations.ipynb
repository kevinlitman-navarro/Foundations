# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using Selenium for this, *not* BeautifulSoup and requests.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait 
import pandas as pd

driver = webdriver.Chrome()

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for cosmetologist violations for people with the last name **Nguyen**.

# %%
driver.get('https://www.tdlr.texas.gov/cimsfo/fosearch.asp')

# %%
dropdown = driver.find_element_by_name('pht_status')
select = Select(dropdown)
select.select_by_visible_text('Cosmetologists')

# %%
last_name = driver.find_element_by_name('pht_lnm')
last_name.send_keys("Nguyen")

# %%
button = driver.find_element_by_xpath('//*[@id="dat-menu"]/div/div[2]/div/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[18]/td/input[1]')
button.click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this.

# %% [markdown]
# ### Loop through each result and print the entire row
#
# Okay wait, that's a heck of a lot. Use `[:10]` to only do the first ten (`listname[:10]` gives you the first ten).

# %%
listings = driver.find_elements_by_tag_name('tr')

for listing in listings[:10]:
    print("----------")
    print(listing.text)
# Out:
# ----------
# Name and Location Order Basis for Order
# ----------
# NGUYEN, TOAN HUU
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78217
#
#
# License #(s): 780948, 1706491, 1699123
#
# Complaint # COS20180004289 Date: 5/30/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# ----------
# NGUYEN, HANH CONG
# City: EL PASO
# County: EL PASO
# Zip Code: 79934
#
#
# License #: 737708
#
# Complaint # COS20180006594 Date: 5/30/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# ----------
# NGUYEN, KHIEM VAN
# City: LONGVIEW
# County: GREGG
# Zip Code: 75604
#
#
# License #: 731665
#
# Complaint # COS20180000257 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,250. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# ----------
# NGUYEN, DIEP THI NGOC
# City: HOUSTON
# County: HARRIS
# Zip Code: 77014
#
#
# License #(s): 1347649, 760528
#
# Complaint # COS20180004915 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client.
# ----------
# NGUYEN, LAN T-THUY
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78255
#
# NGUYEN, SAMLOI
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78255
#
#
# License #: 767339
#
# Complaint # COS20180009255 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $575. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# ----------
# NGUYEN, TUAN A
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78723
#
# NGUYEN, TUAN VAN
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76011
#
#
# License #: 681274
#
# Complaint # COS20140018343 Date: 5/9/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to clean and disinfect all wax pots; Respondent failed to disinfect tools, implements, and supplies with a hospital-grade EPA-registered disinfectant solution; Respondent failed to replace materials that contact skin, or skin products from multi-use containers, with new or clean articles for each client.
# ----------
# NGUYEN, THAO B
# City: EULESS
# County: TARRANT
# Zip Code: 76039
#
#
# License #(s): 721373, 1142884
#
# Complaint # COS20180008846 Date: 5/9/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# ----------
# NGUYEN, BETH MARIA
# City: HOUSTON
# County: HARRIS
# Zip Code: 77083
#
#
# License #: 1470271
#
# Complaint # COS20180000897 Date: 4/30/2018
#
# Respondent's Cosmetology Operator license was revoked by operation of law on 03/29/16. The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# ----------
# NGUYEN, TRUNG N
# City: AMARILLO
# County: POTTER
# Zip Code: 79106
#
#
# License #(s): 1196244, 767015, 767014
#
# Complaint # COS20170023893 Date: 4/25/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,300. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    try to do something
# except:
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything, you can type `pass` instead of the `print` statement.
#
# **Why doesn't the first one have a name?**

# %%
for listing in listings:
    try:
        print("----------")
        print(listing.find_elements_by_class_name("results_text")[0].text)
    except:
        pass
# Out:
# ----------
# ----------
# NGUYEN, TOAN HUU
# ----------
# NGUYEN, HANH CONG
# ----------
# NGUYEN, KHIEM VAN
# ----------
# NGUYEN, DIEP THI NGOC

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: You can get the HTML of something by doing `.get_attribute('innerHTML')` - it might help you diagnose your issue.*
# > - *Tip: Or I guess you could just skip the one with the problem...

# %%
for listing in listings:
    try:
        print("----------")
        print(listing.find_elements_by_tag_name("td")[2].text)
    except:
        pass
# Out:
# ----------
# ----------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# ----------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# ----------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# ----------
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client.

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# - TIP: Think about the order of the elements

# %%
for listing in listings:
    try:
        print("----------")
        print(listing.find_elements_by_class_name("results_text")[5].text)
    except:
        pass
# Out:
# ----------
# ----------
# COS20180004289
# ----------
# COS20180006594
# ----------
# COS20180000257
# ----------
# COS20180004915

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# > *Tip: If you want to ask for the "next sibling," you can't use `find_next_sibling` in Selenium, you need to use `element.find_element_by_xpath("following-sibling::div")` to find the next div, or `element.find_element_by_xpath("following-sibling::*")` to find the next anything.

# %%
rows = []

for listing in listings:
    row = {}
    try:
        
        #Person's name
        
        name = listing.find_elements_by_class_name("results_text")[0].text
        #print(name)
        row['name'] = name
        
        #Violation description
        
        violation_description = listing.find_elements_by_tag_name("td")[2].text
        #print(violation_description)
        row['violation_description'] = violation_description
        
        #Violation number
        
        violation_number = listing.find_elements_by_class_name("results_text")[5].text
        #print(violation_number)
        row['violation_number'] = violation_number
        
        #License Numbers
        
        license_number = listing.find_elements_by_class_name("results_text")[4].text
        #print(license_number)
        row['license_number'] = license_number
        
        #Zip Code
        
        zip_code = listing.find_elements_by_class_name("results_text")[3].text
        #print(zip_code)
        row['zip_code'] = zip_code
        
        #County
        
        county = listing.find_elements_by_class_name("results_text")[2].text
        #print(county)
        row['county'] = county
        
        #City
        
        city = listing.find_elements_by_class_name("results_text")[1].text
        #print(city)
        row['city'] = city
        
        rows.append(row)
        
    except:
          pass


rows
# Out:
# [{'name': 'NGUYEN, TOAN HUU',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180004289',
#   'license_number': '780948, 1706491, 1699123',
#   'zip_code': '78217',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, HANH CONG',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.',
#   'violation_number': 'COS20180006594',
#   'license_number': '737708',
#   'zip_code': '79934',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, KHIEM VAN',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.',
#   'violation_number': 'COS20180000257',
#   'license_number': '731665',
#   'zip_code': '75604',
#   'county': 'GREGG',
#   'city': 'LONGVIEW'},
#  {'name': 'NGUYEN, DIEP THI NGOC',
#   'violation_description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client.',
#   'violation_number': 'COS20180004915',
#   'license_number': '1347649, 760528',
#   'zip_code': '77014',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, LAN T-THUY',
#   'violation_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'violation_number': 'SAN ANTONIO',
#   'license_number': 'NGUYEN, SAMLOI',
#   'zip_code': '78255',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, TUAN A',
#   'violation_description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to disinfect tools, implements, and supplies with a hospital-grade EPA-registered disinfectant solution; Respondent failed to replace materials that contact skin, or skin products from multi-use containers, with new or clean articles for each client.',
#   'violation_number': 'ARLINGTON',
#   'license_number': 'NGUYEN, TUAN VAN',
#   'zip_code': '78723',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, THAO B',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180008846',
#   'license_number': '721373, 1142884',
#   'zip_code': '76039',
#   'county': 'TARRANT',
#   'city': 'EULESS'},
#  {'name': 'NGUYEN, BETH MARIA',
#   'violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'violation_number': 'COS20180000897',
#   'license_number': '1470271',
#   'zip_code': '77083',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, TRUNG N',
#   'violation_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'violation_number': 'COS20170023893',
#   'license_number': '1196244, 767015, 767014',
#   'zip_code': '79106',
#   'county': 'POTTER',
#   'city': 'AMARILLO'},
#  {'name': 'NGUYEN, NGAT THI',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'violation_number': 'COS20180004076',
#   'license_number': '759931',
#   'zip_code': '75686',
#   'county': 'CAMP',
#   'city': 'PITTSBURG'},
#  {'name': 'NGUYEN, KELLY PHUONG N',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180004498',
#   'license_number': '751553, 1442491',
#   'zip_code': '78413',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, CHAU THI',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180008220',
#   'license_number': '749847, 1656235, 1564805, 1588030',
#   'zip_code': '77901',
#   'county': 'VICTORIA',
#   'city': 'VICTORIA'},
#  {'name': 'NGUYEN, XUAN T',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170009055',
#   'license_number': '765777',
#   'zip_code': '77396',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, THANH C',
#   'violation_description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'violation_number': 'COS20180002334',
#   'license_number': '772982',
#   'zip_code': '77072',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, HAI',
#   'violation_description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'violation_number': 'COS20170019449',
#   'license_number': '748395, 1130422',
#   'zip_code': '75071',
#   'county': 'COLLIN',
#   'city': 'MCKINNEY'},
#  {'name': 'NGUYEN, JENNIFER T',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170021681',
#   'license_number': '747241',
#   'zip_code': '79912',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, TONY VAN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180004089',
#   'license_number': '747322',
#   'zip_code': '78230',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, HANH THAO TRAN',
#   'violation_description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'violation_number': 'COS20180004300',
#   'license_number': '760398',
#   'zip_code': '78413',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, QUYEN THI MAI',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180004340',
#   'license_number': '761225',
#   'zip_code': '76502',
#   'county': 'BELL',
#   'city': 'TEMPLE'},
#  {'name': 'NGUYEN, OANH THI',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'violation_number': 'COS20180004475',
#   'license_number': '770502, 1659747, 141034, 1446030',
#   'zip_code': '77351',
#   'county': 'POLK',
#   'city': 'LIVINGSTON'},
#  {'name': 'NGUYEN, THU NHU',
#   'violation_description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'violation_number': 'COS20180004720',
#   'license_number': '759576, 1329001',
#   'zip_code': '75212',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, PHUNG THI',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to dispose of single use items after each use.',
#   'violation_number': 'COS20180004864',
#   'license_number': '760804',
#   'zip_code': '77979',
#   'county': 'CALHOUN',
#   'city': 'PORT LAVACA'},
#  {'name': 'NGUYEN, TUAN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180006279',
#   'license_number': '670177, 1114970',
#   'zip_code': '78414',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, PHUOC BA',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180004329',
#   'license_number': '1552617',
#   'zip_code': '78250',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, THAI VAN',
#   'violation_description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and disinfect all wax pots.',
#   'violation_number': 'COS20170020336',
#   'license_number': '733384, 1187211',
#   'zip_code': '75040',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, JIMMY',
#   'violation_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'violation_number': 'COS20180000630',
#   'license_number': '740004',
#   'zip_code': '76541',
#   'county': 'BELL',
#   'city': 'KILLEEN'},
#  {'name': 'NGUYEN, QUI VAN',
#   'violation_description': 'Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.',
#   'violation_number': 'COS20180003692',
#   'license_number': '782276, 1148074',
#   'zip_code': '76002',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, KIM LIEN TRAN',
#   'violation_description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'violation_number': 'COS20180002266',
#   'license_number': '742883, 1622377',
#   'zip_code': '77407',
#   'county': 'FORT BEND',
#   'city': 'RICHMOND'},
#  {'name': 'NGUYEN, THUY HONG',
#   'violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'violation_number': 'COS20180003857',
#   'license_number': '1198494, 762214',
#   'zip_code': '75054',
#   'county': 'DALLAS',
#   'city': 'GRAND PRAIRIE'},
#  {'name': 'NGUYEN, TRANG YEN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180004081',
#   'license_number': '776942',
#   'zip_code': '76504',
#   'county': 'BELL',
#   'city': 'TEMPLE'},
#  {'name': 'NGUYEN, BINH THANH',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180005797',
#   'license_number': '736301',
#   'zip_code': '76018',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, MUA THI',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170018997',
#   'license_number': '757973',
#   'zip_code': '75033',
#   'county': 'COLLIN',
#   'city': 'FRISCO'},
#  {'name': 'NGUYEN, TRUNG H',
#   'violation_description': 'Respondent failed to properly disinfect implements at the end of each day.',
#   'violation_number': 'COS20180002614',
#   'license_number': '1339734',
#   'zip_code': '78244',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, TRANG N',
#   'violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'violation_number': 'COS20180003845',
#   'license_number': '1052681',
#   'zip_code': '75206',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, PHUONG TUYET TH',
#   'violation_description': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.',
#   'violation_number': 'COS20170008359',
#   'license_number': '1689225',
#   'zip_code': '36502',
#   'county': 'OUT OF STATE',
#   'city': 'ATMORE'},
#  {'name': 'NGUYEN, KIM AN THI',
#   'violation_description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'violation_number': 'COS20180004075',
#   'license_number': '739743',
#   'zip_code': '77022',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, DUC V',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20170021316',
#   'license_number': 'Not Licensed',
#   'zip_code': '75402',
#   'county': 'HUNT',
#   'city': 'GREENVILLE'},
#  {'name': 'NGUYEN, DUC VAN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.',
#   'violation_number': 'COS20170022035',
#   'license_number': '693169',
#   'zip_code': '78504',
#   'county': 'HIDALGO',
#   'city': 'MCALLEN'},
#  {'name': 'NGUYEN, AN QUY',
#   'violation_description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'violation_number': 'COS20180004639',
#   'license_number': '751433, 1083641',
#   'zip_code': '78249',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, TONY H',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170009421',
#   'license_number': '1287777',
#   'zip_code': '79761',
#   'county': 'ECTOR',
#   'city': 'ODESSA'},
#  {'name': 'NGUYEN, PHUONG THAO THI',
#   'violation_description': "Respondent allowed an unlicensed individual to fraudulently use Respondent's license as their own.",
#   'violation_number': 'COS20180003532',
#   'license_number': '1633919',
#   'zip_code': '79014',
#   'county': 'HEMPHILL',
#   'city': 'CANADIAN'},
#  {'name': 'NGUYEN, CHINH K',
#   'violation_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'violation_number': 'COS20180004016',
#   'license_number': '777067',
#   'zip_code': '76502',
#   'county': 'BELL',
#   'city': 'TEMPLE'},
#  {'name': 'NGUYEN, SAM',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.',
#   'violation_number': 'COS20170022895',
#   'license_number': '727612',
#   'zip_code': '76262',
#   'county': 'DENTON',
#   'city': 'TROPHY CLUB'},
#  {'name': 'NGUYEN, HUE T',
#   'violation_description': 'Respondent operated a cosmetology salon without the appropriate license.',
#   'violation_number': 'COS20180001881',
#   'license_number': '1258687',
#   'zip_code': '77070',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, TAM VAN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170017965',
#   'license_number': '769113, 1657662, 1186201, 1270402',
#   'zip_code': '78261',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, CAM THI',
#   'violation_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'violation_number': 'COS20180001081',
#   'license_number': '694370',
#   'zip_code': '78041',
#   'county': 'WEBB',
#   'city': 'LAREDO'},
#  {'name': 'NGUYEN, HONG THI ANH',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20180001141',
#   'license_number': 'Not Licensed',
#   'zip_code': '78249',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, HUYEN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required.',
#   'violation_number': 'COS20180003707',
#   'license_number': '686742',
#   'zip_code': '77066',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, TOAN MINH',
#   'violation_description': 'Respondent failed to clean and disinfect all wax pots.',
#   'violation_number': 'COS20170014082',
#   'license_number': '772484',
#   'zip_code': '75218',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, SONNY T',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180001604',
#   'license_number': '777225',
#   'zip_code': '78249',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, HOANG THI',
#   'violation_description': "Respondent offered specialty cosmetology services outside the scope of Respondent's specialty salon license.",
#   'violation_number': 'COS20180000225',
#   'license_number': 'Not Licensed',
#   'zip_code': '76116',
#   'county': 'TARRANT',
#   'city': 'FORT WORTH'},
#  {'name': 'NGUYEN, NHUNG TUYET',
#   'violation_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'violation_number': 'COS20170022848',
#   'license_number': '695790',
#   'zip_code': '79924',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, TOQUYEN',
#   'violation_description': 'Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.',
#   'violation_number': 'COS20180002313',
#   'license_number': '742460',
#   'zip_code': '75052',
#   'county': 'DALLAS',
#   'city': 'GRAND PRAIRIE'},
#  {'name': 'NGUYEN, LY V',
#   'violation_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'violation_number': 'COS20180002216',
#   'license_number': '735441',
#   'zip_code': '78223',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, NAM QUANG',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'violation_number': 'COS20180000650',
#   'license_number': '745552',
#   'zip_code': '76542',
#   'county': 'BELL',
#   'city': 'KILLEEN'},
#  {'name': 'NGUYEN, KHANH NGOC',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180001594',
#   'license_number': '778428',
#   'zip_code': '78130',
#   'county': 'COMAL',
#   'city': 'NEW BRAUNFELS'},
#  {'name': 'NGUYEN, HO PHI',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required',
#   'violation_number': 'COS20180002227',
#   'license_number': '750285',
#   'zip_code': '78748',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, NAM HUU',
#   'violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'violation_number': 'COS20170018593',
#   'license_number': '1166036, 757967',
#   'zip_code': '76502',
#   'county': 'BELL',
#   'city': 'TEMPLE'},
#  {'name': 'NGUYEN, VINH',
#   'violation_description': "Respondent offered specialty cosmetology services outside the scope of Respondent's specialty salon license; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.",
#   'violation_number': 'COS20170019077',
#   'license_number': '762988',
#   'zip_code': '75052',
#   'county': 'DALLAS',
#   'city': 'GRAND PRAIRIE'},
#  {'name': 'NGUYEN, LOI',
#   'violation_description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'violation_number': 'COS20170022385',
#   'license_number': '654211',
#   'zip_code': '78577',
#   'county': 'HIDALGO',
#   'city': 'PHARR'},
#  {'name': 'NGUYEN, TUAN A',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20170022737',
#   'license_number': '1735127',
#   'zip_code': '77083',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, CHRISTY THU',
#   'violation_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180000914',
#   'license_number': '743531',
#   'zip_code': '78232',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, JOSEPH HUY',
#   'violation_description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'violation_number': 'COS20170008502',
#   'license_number': '743744',
#   'zip_code': '77642',
#   'county': 'JEFFERSON',
#   'city': 'PORT ARTHUR'},
#  {'name': 'NGUYEN, PHUONG T',
#   'violation_description': 'Respondent left applicators standing in the wax.',
#   'violation_number': 'COS20170015324',
#   'license_number': '766293',
#   'zip_code': '75023',
#   'county': 'COLLIN',
#   'city': 'PLANO'},
#  {'name': 'NGUYEN, ANTHONY N',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20170020893',
#   'license_number': 'Not Licensed',
#   'zip_code': '77014',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, PETER D',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to clean and disinfect all wax pots.',
#   'violation_number': 'COS20170022810',
#   'license_number': '760304',
#   'zip_code': '79936',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, THAI BA',
#   'violation_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'violation_number': 'COS20180001343',
#   'license_number': '777363',
#   'zip_code': '78665',
#   'county': 'WILLIAMSON',
#   'city': 'ROUND ROCK'},
#  {'name': 'NGUYEN, THIEN BA',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20180001354',
#   'license_number': '1735222',
#   'zip_code': '75287',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, THUY T',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170008527',
#   'license_number': '747327',
#   'zip_code': '75243',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, LINH THI',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'violation_number': 'COS20170020171',
#   'license_number': '716550',
#   'zip_code': '75503',
#   'county': 'BOWIE',
#   'city': 'TEXARKANA'},
#  {'name': 'NGUYEN, VAN QUOC',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170020811',
#   'license_number': '737716',
#   'zip_code': '76016',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, THU',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170021277',
#   'license_number': '776855',
#   'zip_code': '79925',
#   'county': 'EL PASO',
#   'city': 'EL PAS0'},
#  {'name': 'NGUYEN, TRINH K',
#   'violation_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'violation_number': 'COS20170021553',
#   'license_number': '730117',
#   'zip_code': '79904',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, NHIEM THI D',
#   'violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'violation_number': 'COS20170022842',
#   'license_number': '1697972',
#   'zip_code': '75067',
#   'county': 'DENTON',
#   'city': 'LEWISVILLE'},
#  {'name': 'NGUYEN, CATHERINE MINH',
#   'violation_description': 'Respondent failed to clean and disinfect all wax pots.',
#   'violation_number': 'COS20170022983',
#   'license_number': '752191',
#   'zip_code': '78738',
#   'county': 'TRAVIS',
#   'city': 'BEE CAVE'},
#  {'name': 'NGUYEN, HAI DUC',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20170023255',
#   'license_number': '1222442',
#   'zip_code': '78754',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, BILL',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170019854',
#   'license_number': '752445',
#   'zip_code': '78130',
#   'county': 'COMAL',
#   'city': 'NEW BRAUNFELS'},
#  {'name': 'NGUYEN, STACY HOAI',
#   'violation_description': 'Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.',
#   'violation_number': 'COS20170021497',
#   'license_number': '744227',
#   'zip_code': '77008',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, SAMANTHA L',
#   'violation_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'violation_number': 'COS20170023216',
#   'license_number': '771556',
#   'zip_code': '78660',
#   'county': 'TRAVIS',
#   'city': 'PFLUGERVILLE'},
#  {'name': 'NGUYEN, XUAN',
#   'violation_description': 'Respondent failed to clean and disinfect all wax pots.',
#   'violation_number': 'COS20180000163',
#   'license_number': '756928',
#   'zip_code': '75075',
#   'county': 'COLLIN',
#   'city': 'PLANO'},
#  {'name': 'NGUYEN, HUE BICH',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20170021329',
#   'license_number': 'Not Licensed',
#   'zip_code': '78640',
#   'county': 'HAYS',
#   'city': 'KYLE'},
#  {'name': 'NGUYEN, LINH P',
#   'violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'violation_number': 'COS20170021896',
#   'license_number': '1202607',
#   'zip_code': '79072',
#   'county': 'HALE',
#   'city': 'PLAINVIEW'},
#  {'name': 'NGUYEN, TUYET T',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20180000509',
#   'license_number': '770855',
#   'zip_code': '78248',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, DUYEN THANH',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170020526',
#   'license_number': '743322',
#   'zip_code': '78247',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, LE MY',
#   'violation_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'violation_number': 'COS20170017971',
#   'license_number': '725522',
#   'zip_code': '79606',
#   'county': 'TAYLOR',
#   'city': 'ABILENE'},
#  {'name': 'NGUYEN, THAO PHUONG',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170019085',
#   'license_number': '730295',
#   'zip_code': '76137',
#   'county': 'TARRANT',
#   'city': 'FORT WORTH'},
#  {'name': 'NGUYEN, HANG',
#   'violation_description': 'Respondent operated a cosmetology salon with an expired license; Respondent failed to maintain the required cleaning and disinfecting records; Respondent failed to clean and disinfect all wax pots.',
#   'violation_number': 'COS20170008608',
#   'license_number': '748864',
#   'zip_code': '75077',
#   'county': 'DENTON',
#   'city': 'HIGHLAND VILLAGE'},
#  {'name': 'NGUYEN, TRAM HIEN',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'violation_number': 'COS20170017932',
#   'license_number': '711510, 1202668, 1290618',
#   'zip_code': '78253',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, THU LE ANH',
#   'violation_description': 'Respondent operated a cosmetology salon without the appropriate license; Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'violation_number': 'COS20170018059',
#   'license_number': '772309',
#   'zip_code': '78753',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, HUONG THANH',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170018401',
#   'license_number': '747486',
#   'zip_code': '79705',
#   'county': 'MIDLAND',
#   'city': 'MIDLAND'},
#  {'name': 'NGUYEN, HOANG THI',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170018757',
#   'license_number': '714415',
#   'zip_code': '76106',
#   'county': 'TARRANT',
#   'city': 'FORT WORTH'},
#  {'name': 'NGUYEN, MICHAEL',
#   'violation_description': 'Respondent failed to wash their hands with soap and water, or us a liquid hand sanitizer, prior to performing any services.',
#   'violation_number': 'COS20170018788',
#   'license_number': '734255',
#   'zip_code': '78753',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, HAN B',
#   'violation_description': 'Respondent failed to wash their hands with soap and water, or us a liquid hand sanitizer, prior to performing any services.',
#   'violation_number': 'COS20170018838',
#   'license_number': '1332394',
#   'zip_code': '78753',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, PHUONG THAI',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20170018936',
#   'license_number': 'Not Licensed',
#   'zip_code': '78217',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, HUU DAT',
#   'violation_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'violation_number': 'COS20170019144',
#   'license_number': '756237',
#   'zip_code': '75044',
#   'county': 'TRAVIS',
#   'city': 'GARNALD'},
#  {'name': 'NGUYEN, LOAN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170019151',
#   'license_number': '751991',
#   'zip_code': '78258',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, TRACY T',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170019180',
#   'license_number': '735289',
#   'zip_code': '78240',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, HANH TUYET T',
#   'violation_description': 'Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.',
#   'violation_number': 'COS20170013466',
#   'license_number': '689532',
#   'zip_code': '75085',
#   'county': 'DALLAS',
#   'city': 'RICHARDSON'},
#  {'name': 'NGUYEN, THAO THI',
#   'violation_description': 'Respondent operated a cosmetology salon with an expired license.',
#   'violation_number': 'COS20170015622',
#   'license_number': '769542, 1233146, 1286561',
#   'zip_code': '78665',
#   'county': 'WILLIAMSON',
#   'city': 'ROUND ROCK'},
#  {'name': 'NGUYEN, JACKLYN HOA T',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170018477',
#   'license_number': '723152',
#   'zip_code': '79714',
#   'county': 'ANDREWS',
#   'city': 'ANDREWS'},
#  {'name': 'NGUYEN, ANHDUNG L',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'violation_number': 'COS20170017450',
#   'license_number': '727144',
#   'zip_code': '78041',
#   'county': 'WEBB',
#   'city': 'LAREDO'},
#  {'name': 'NGUYEN, TRANG YEN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170017697',
#   'license_number': '755659, 1517082, 1544117',
#   'zip_code': '76504',
#   'county': 'BELL',
#   'city': 'TEMPLE'},
#  {'name': 'NGUYEN, MAI THI BACH',
#   'violation_description': "Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.",
#   'violation_number': 'COS20170018218',
#   'license_number': '725831',
#   'zip_code': '76010',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, LE MI',
#   'violation_description': 'Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.',
#   'violation_number': 'COS20160023356',
#   'license_number': '746845',
#   'zip_code': '77066',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, QUY PHUC',
#   'violation_description': 'Respondent failed to dispose of single use items after each use; Respondent left applicators standing in the wax; Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'violation_number': 'COS20170002139',
#   'license_number': '724792',
#   'zip_code': '78415',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, NELSON DONG',
#   'violation_description': 'Respondent employed a person as an operator who did not hold a license.',
#   'violation_number': 'COS20170013748',
#   'license_number': '736834, 1133235',
#   'zip_code': '77450',
#   'county': 'HARRIS',
#   'city': 'KATY'},
#  {'name': 'NGUYEN, NHUT DONG',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.',
#   'violation_number': 'COS20170013993',
#   'license_number': '763570, 1586256',
#   'zip_code': '79934',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, CINDY KIM',
#   'violation_description': 'Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry; Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'violation_number': 'COS20170017073',
#   'license_number': '711857',
#   'zip_code': '75052',
#   'county': 'DALLAS',
#   'city': 'GRAND PRAIRIE'},
#  {'name': 'NGUYEN, LAN AI',
#   'violation_description': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to maintain a list of all renters.',
#   'violation_number': 'COS20170012519',
#   'license_number': '761110',
#   'zip_code': '77075',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, HAI',
#   'violation_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'violation_number': 'COS20170007552',
#   'license_number': '747172',
#   'zip_code': '79938',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, HIEP THI NGOC',
#   'violation_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'violation_number': 'COS20170015532',
#   'license_number': '765410, 1099895, 1566404',
#   'zip_code': '79928',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, KATHY SUONG',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170016587',
#   'license_number': '758663',
#   'zip_code': '78629',
#   'county': 'GONZALES',
#   'city': 'GONZALES'},
#  {'name': 'NGUYEN, KEVIN THANH',
#   'violation_description': 'Respondent leased space in a salon to multiple individuals who engaged in the practice of cosmetology without a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'violation_number': 'COS20170017371',
#   'license_number': '732402',
#   'zip_code': '79705',
#   'county': 'MIDLAND',
#   'city': 'MIDLAND'},
#  {'name': 'NGUYEN, THI N',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20170008194',
#   'license_number': 'Not Licensed',
#   'zip_code': '77573',
#   'county': 'GALVESTON',
#   'city': 'LEAGUE CITY'},
#  {'name': 'NGUYEN, TRUNG H',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170014231',
#   'license_number': '741793',
#   'zip_code': '78249',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, THAN H VAN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170016226',
#   'license_number': '740829',
#   'zip_code': '78216',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, NHUNG TUYET',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170004029',
#   'license_number': '695790, 1268166, 1103243',
#   'zip_code': '79924',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, QUOC',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent operated a cosmetology salon with an expired license.',
#   'violation_number': 'COS20170009322',
#   'license_number': '748178, 768249',
#   'zip_code': '75110',
#   'county': 'NAVARRO',
#   'city': 'CORSICANA'},
#  {'name': 'NGUYEN, CINDY',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'violation_number': 'COS20170012608',
#   'license_number': '737204',
#   'zip_code': '76504',
#   'county': 'BELL',
#   'city': 'TEMPLE'},
#  {'name': 'NGUYEN, CHIEN DINH',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'violation_number': 'COS20160022481',
#   'license_number': '729111, 746437',
#   'zip_code': '78043',
#   'county': 'WEBB',
#   'city': 'LAREDO'},
#  {'name': 'NGUYEN, SAN-SAN THI',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'violation_number': 'COS20160023225',
#   'license_number': '723748',
#   'zip_code': '75074',
#   'county': 'COLLIN',
#   'city': 'PLANO'},
#  {'name': 'NGUYEN, CHAU MINH',
#   'violation_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'violation_number': 'COS20170008609',
#   'license_number': '721939',
#   'zip_code': '78040',
#   'county': 'WEBB',
#   'city': 'LAREDO'},
#  {'name': 'NGUYEN, TUYEN THI B',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20170011174',
#   'license_number': 'Not Licensed',
#   'zip_code': '78660',
#   'county': 'TRAVIS',
#   'city': 'PFLUGERVILLE'},
#  {'name': 'NGUYEN, NGUYEN TO',
#   'violation_description': 'Respondent employed an individual who performed services outside the scope of their specialty license.',
#   'violation_number': 'COS20170011299',
#   'license_number': '758998',
#   'zip_code': '77338',
#   'county': 'HARRIS',
#   'city': 'HUMBLE'},
#  {'name': 'NGUYEN, THAO',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'violation_number': 'COS20170011325',
#   'license_number': '745705',
#   'zip_code': '78244',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, LIEN T',
#   'violation_description': 'Respondent left applicators standing in the wax.',
#   'violation_number': 'COS20170011733',
#   'license_number': '733291',
#   'zip_code': '75007',
#   'county': 'DALLAS',
#   'city': 'CARROLLTON'},
#  {'name': 'NGUYEN, TAM T',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'violation_number': 'COS20170012580',
#   'license_number': '769686',
#   'zip_code': '78006',
#   'county': 'KENDALL',
#   'city': 'BOERNE'},
#  {'name': 'NGUYEN, HUNG V',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170012636',
#   'license_number': '744022',
#   'zip_code': '78216',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, VAN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170012640',
#   'license_number': '745994',
#   'zip_code': '76708',
#   'county': 'MCLENNAN',
#   'city': 'WACO'},
#  {'name': 'NGUYEN, KENNY KHANH',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'violation_number': 'COS20170009694',
#   'license_number': '734964',
#   'zip_code': '78641',
#   'county': 'WILLIAMSON',
#   'city': 'LEANDER'},
#  {'name': 'NGUYEN, VIVIAN',
#   'violation_description': 'Respondent practiced cosmetology services in an unlicensed beauty salon.',
#   'violation_number': 'COS20160015516',
#   'license_number': '1669595',
#   'zip_code': '77079',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, HONG',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20170008706',
#   'license_number': 'Not Licensed',
#   'zip_code': '75040',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, HUONG THITHANH',
#   'violation_description': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.',
#   'violation_number': 'COS20160000361',
#   'license_number': 'Not Licensed',
#   'zip_code': '76014',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, TUAN',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'violation_number': 'COS20160014677',
#   'license_number': '743941',
#   'zip_code': '78744',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, HOA',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to dispose of single use items after each use.',
#   'violation_number': 'COS20160022089',
#   'license_number': '763482',
#   'zip_code': '79118',
#   'county': 'POTTER',
#   'city': 'AMARILLO'},
#  {'name': 'NGUYEN, LAN H',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20170000008',
#   'license_number': '736997',
#   'zip_code': '79360',
#   'county': 'GAINES',
#   'city': 'SEMINOLE'},
#  {'name': 'NGUYEN, TUAN A',
#   'violation_description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.',
#   'violation_number': 'COS20170003344',
#   'license_number': '681274',
#   'zip_code': '78723',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, TUAN A',
#   'violation_description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.',
#   'violation_number': 'COS20170003436',
#   'license_number': '681274',
#   'zip_code': '78723',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, PHUONG L',
#   'violation_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'violation_number': 'COS20170006047',
#   'license_number': '733461',
#   'zip_code': '75035',
#   'county': 'COLLIN',
#   'city': 'FRISCO'},
#  {'name': 'NGUYEN, TONY VAN',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly. Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'violation_number': 'COS20170008287',
#   'license_number': '747322',
#   'zip_code': '78230',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, MAI TRINH',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.',
#   'violation_number': 'COS20170009201',
#   'license_number': '759330',
#   'zip_code': '77357',
#   'county': 'MONTGOMERY',
#   'city': 'NEW CANEY'},
#  {'name': 'NGUYEN, HANH THAO TRAN',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20160017824',
#   'license_number': '1404315',
#   'zip_code': '78413',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, KENNEY TUAN',
#   'violation_description': 'Respondent failed to have a wet disinfectant container.',
#   'violation_number': 'COS20170004672',
#   'license_number': '692892',
#   'zip_code': '78613',
#   'county': 'WILLIAMSON',
#   'city': 'CEDAR PARK'},
#  {'name': 'NGUYEN, KHOI T',
#   'violation_description': 'Respondent left applicators standing in the wax.',
#   'violation_number': 'COS20170005623',
#   'license_number': '712440',
#   'zip_code': '75154',
#   'county': 'Ellis',
#   'city': 'RED OAK'},
#  {'name': 'NGUYEN, THANG',
# ...
#   'violation_number': 'COS20150011884',
#   'license_number': '744894',
#   'zip_code': '75035',
#   'county': 'COLLIN',
#   'city': 'FRISCO'},
#  {'name': 'NGUYEN, THANH HUYNH THI',
#   'violation_description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'violation_number': 'COS20150022073',
#   'license_number': '718676',
#   'zip_code': '75702',
#   'county': 'SMITH',
#   'city': 'TYLER'},
#  {'name': 'NGUYEN, HONG ANH',
#   'violation_description': 'Respondent leased space in a salon to multiple individuals who engaged in the practice of cosmetology without a cosmetology license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20150019662',
#   'license_number': '756072',
#   'zip_code': '77065',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, MINH HUONG THI',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20150021205',
#   'license_number': '685121',
#   'zip_code': '76039',
#   'county': 'TARRANT',
#   'city': 'EULESS'},
#  {'name': 'NGUYEN, QUANG XUAN',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.',
#   'violation_number': 'COS20140017430',
#   'license_number': '738063',
#   'zip_code': '75180',
#   'county': 'DALLAS',
#   'city': 'BALCH SPRINGS'},
#  {'name': 'NGUYEN, KATRINA KHANH',
#   'violation_description': 'Respondent failed to disinfect tools, implements, and supplies with a hospital-grade EPA-registered disinfectant solution.',
#   'violation_number': 'COS20150004672',
#   'license_number': '746036',
#   'zip_code': '77578',
#   'county': 'BRAZORIA',
#   'city': 'MANVEL'},
#  {'name': 'NGUYEN, PHUNG THI',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent failed to disinfect tools, implements, and supplies with a hospital-grade EPA-registered disinfectant solution.',
#   'violation_number': 'COS20150004749',
#   'license_number': '729124',
#   'zip_code': '77064',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, NHU THUY',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology with an expired cosmetology license; Respondent failed to wash towels in hot water and chlorine bleach.',
#   'violation_number': 'COS20150017956',
#   'license_number': '757019',
#   'zip_code': '75052',
#   'county': 'DALLAS',
#   'city': 'GRAND PRAIRIE'},
#  {'name': 'NGUYEN, CAROL P',
#   'violation_description': 'Respondent operated a cosmetology salon without the appropriate license.',
#   'violation_number': 'COS20150018968',
#   'license_number': '756755',
#   'zip_code': '78861',
#   'county': 'MEDINA',
#   'city': 'HONDO'},
#  {'name': 'NGUYEN, THU HONG THI',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'COS20150020422',
#   'license_number': '743867',
#   'zip_code': '75103',
#   'county': 'VAN ZANDT',
#   'city': 'CANTON'},
#  {'name': 'NGUYEN, THIEN T',
#   'violation_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20140021098',
#   'license_number': '746682',
#   'zip_code': '76210',
#   'county': 'DENTON',
#   'city': 'DENTON'},
#  {'name': 'NGUYEN, RYAN H',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required before use by each patron.',
#   'violation_number': 'COS20150017345',
#   'license_number': '750804',
#   'zip_code': '77845',
#   'county': 'BRAZOS',
#   'city': 'COLLEGE STATION'},
#  {'name': 'NGUYEN, ANH THI MAI',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'violation_number': 'COS20150018536',
#   'license_number': '720844',
#   'zip_code': '77070',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, DUNG THI THU',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology with an expired cosmetology license.',
#   'violation_number': 'COS20140010296',
#   'license_number': '728670',
#   'zip_code': '78249',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, TOAN KIM',
#   'violation_description': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent failed to dispose of after each use all wax that has been in contact with a client's skin",
#   'violation_number': 'COS20140015043',
#   'license_number': '690894',
#   'zip_code': '78526',
#   'county': 'CAMERON',
#   'city': 'BROWNSVILLE'},
#  {'name': 'NGUYEN, DUNG THI THU',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology with an expired cosmetology license.',
#   'violation_number': 'COS20150003298',
#   'license_number': '728670',
#   'zip_code': '78249',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, THE THI',
#   'violation_description': 'Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client; Respondent operated a cosmetology salon with an expired license; Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'violation_number': 'COS20150006123',
#   'license_number': '728111',
#   'zip_code': '79336',
#   'county': 'HOCKLEY',
#   'city': 'LEVELLAND'},
#  {'name': 'NGUYEN, TUYET THI',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20150015333',
#   'license_number': '689293',
#   'zip_code': '78621',
#   'county': 'BASTROP',
#   'city': 'ELGIN'},
#  {'name': 'NGUYEN, DUNG CHI',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent failed to clean and disinfect all wax pots.',
#   'violation_number': 'COS20150021591',
#   'license_number': '752201',
#   'zip_code': '79928',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, CUONG D',
#   'violation_description': "Respondent failed to submit an electronic record of a student's accrued clock hours once per month; Respondent obtained permits for students who did not reside in the State of Texas.",
#   'violation_number': 'COS20150000380',
#   'license_number': '702735',
#   'zip_code': '76013',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, THU THI',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20150016796',
#   'license_number': '741821',
#   'zip_code': '79424',
#   'county': 'LUBBOCK',
#   'city': 'LUBBOCK'},
#  {'name': 'NGUYEN, DI VAN',
#   'violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'violation_number': 'COS20150018132',
#   'license_number': '743580, 1072049',
#   'zip_code': '75044',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, TOM THO',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20150015343',
#   'license_number': '727869',
#   'zip_code': '79423',
#   'county': 'LUBBOCK',
#   'city': 'LUBBOCK'},
#  {'name': 'NGUYEN, NGOC THUY THI',
#   'violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'violation_number': 'COS20150004196',
#   'license_number': '1036531, 728535',
#   'zip_code': '77573',
#   'county': 'GALVESTON',
#   'city': 'LEAGUE CITY'},
#  {'name': 'NGUYEN, TIFFANIE CHI',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20150018110',
#   'license_number': '756382',
#   'zip_code': '79424',
#   'county': 'LUBBOCK',
#   'city': 'LUBBOCK'},
#  {'name': 'NGUYEN, PAMELA',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20150018924',
#   'license_number': '735578',
#   'zip_code': '77581',
#   'county': 'BRAZORIA',
#   'city': 'PEARLAND'},
#  {'name': 'NGUYEN, THAI HOANG',
#   'violation_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'violation_number': 'COS20140008360',
#   'license_number': 'Not Licensed',
#   'zip_code': '75048',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, BILLY',
#   'violation_description': 'Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to wash towels in hot water and chlorine bleach; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20150010961',
#   'license_number': '752949',
#   'zip_code': '77084',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, THU T',
#   'violation_description': 'Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20150011167',
#   'license_number': '668738',
#   'zip_code': '77064',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, YEN THI',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20150000112',
#   'license_number': '718244',
#   'zip_code': '79424',
#   'county': 'LUBBOCK',
#   'city': 'LUBBOCK'},
#  {'name': 'NGUYEN, HA THITHU',
#   'violation_description': 'Respondent operated a cosmetology salon without the appropriate license.',
#   'violation_number': 'COS20140019397',
#   'license_number': '687901',
#   'zip_code': '77584',
#   'county': 'BRAZORIA',
#   'city': 'PEARLAND'},
#  {'name': 'NGUYEN, TUYET T',
#   'violation_description': 'Respondent operated a cosmetology salon without the appropriate license.',
#   'violation_number': 'COS20150011271',
#   'license_number': '729219',
#   'zip_code': '77083',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, KELLY PHUONG N',
#   'violation_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'violation_number': 'COS20150014794',
#   'license_number': '751553',
#   'zip_code': '78413',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, CAROLEE H',
#   'violation_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'violation_number': 'COS20150015861',
#   'license_number': '750393',
#   'zip_code': '77379',
#   'county': 'HARRIS',
#   'city': 'SPRING'},
#  {'name': 'NGUYEN, THI LAN',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.',
#   'violation_number': 'COS20150020881',
#   'license_number': '737066',
#   'zip_code': '77009',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, JOHNNY-HUY K',
#   'violation_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'COS20130020346',
#   'license_number': '742538',
#   'zip_code': '77084',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, MARK TRONG',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning.',
#   'violation_number': 'PAMPA',
#   'license_number': 'NGUYEN, TY QUANG',
#   'zip_code': '79065',
#   'county': 'GRAY',
#   'city': 'PAMPA'},
#  {'name': 'NGUYEN, HOA THI',
#   'violation_description': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.',
#   'violation_number': 'COS20140013340',
#   'license_number': '1587456',
#   'zip_code': '35173',
#   'county': 'JEFFERSON',
#   'city': 'TRUSSVILLE'},
#  {'name': 'NGUYEN, DANH CHI',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron; Respondent failed to comply with an order previously issued by the Executive Director.',
#   'violation_number': 'COS20150000413',
#   'license_number': '691596, 1099273',
#   'zip_code': '76010',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, SON THI',
#   'violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'violation_number': 'COS20150006524',
#   'license_number': '714638, 738939, 1307491',
#   'zip_code': '76207',
#   'county': 'DENTON',
#   'city': 'DENTON'},
#  {'name': 'NGUYEN, LIEN THI',
#   'violation_description': "Respondent failed to submit an electronic record of a student's accrued clock hours once per month; Respondent failed to properly account for hours granted to each student.",
#   'violation_number': 'COS20130017203',
#   'license_number': '705186',
#   'zip_code': '75007',
#   'county': 'DALLAS',
#   'city': 'CARROLLTON'},
#  {'name': 'NGUYEN, LIEN THI',
#   'violation_description': "Respondent failed to submit an electronic record of a student's accrued clock hours once per month; Respondent failed to properly account for hours granted to each student.",
#   'violation_number': 'COS20130018307',
#   'license_number': '705186',
#   'zip_code': '75007',
#   'county': 'DALLAS',
#   'city': 'CARROLLTON'},
#  {'name': 'NGUYEN, DUCHOA',
#   'violation_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'violation_number': 'LUBBOCK',
#   'license_number': 'NGUYEN, LUAN THI',
#   'zip_code': '79424',
#   'county': 'LUBBOCK',
#   'city': 'LUBBOCK'}]

# %% [markdown]
# ### Save that to a CSV
#
# - Tip: You'll want to use pandas here

# %%
df = pd.DataFrame(rows)

df

df.to_csv("texas-cosmetology-violations.csv", index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.
